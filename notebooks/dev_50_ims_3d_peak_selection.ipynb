# %%
import logging
from IPython.core.interactiveshell import InteractiveShell
# %load_ext autoreload
InteractiveShell.ast_node_interactivity = "all"

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # Load data

# %% [markdown]
# # Training

# %%
import torch
from torch.utils.data import Dataset, DataLoader

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
from peak_detection_2d.model import PeakDetectionNet
from torchinfo import summary

net = PeakDetectionNet(1, 32)

summary(
    model=net,
    # (batch_size, color_channels, height, width)
    input_size=[(8, 1, 180, 180), (8, 2)],
    col_names=["input_size", "output_size", "num_params"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ====================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #
# ====================================================================================================
# PeakDetectionNet (PeakDetectionNet)      [8, 1, 180, 180]     [8, 4]               --
# ├─Sequential (conv)                      [8, 1, 180, 180]     [8, 4]               --
# │    └─ResBlock (0)                      [8, 1, 180, 180]     [8, 32, 180, 180]    --
# │    │    └─Sequential (base1)           [8, 1, 180, 180]     [8, 1, 180, 180]     12
# │    │    └─Sequential (base2)           [8, 1, 180, 180]     [8, 32, 180, 180]    384
# │    └─MaxPool2d (1)                     [8, 32, 180, 180]    [8, 32, 90, 90]      --
# │    └─ResBlock (2)                      [8, 32, 90, 90]      [8, 64, 90, 90]      --
# │    │    └─Sequential (base1)           [8, 32, 90, 90]      [8, 32, 90, 90]      9,312
# │    │    └─Sequential (base2)           [8, 32, 90, 90]      [8, 64, 90, 90]      18,624
# │    └─MaxPool2d (3)                     [8, 64, 90, 90]      [8, 64, 45, 45]      --
# │    └─ResBlock (4)                      [8, 64, 45, 45]      [8, 128, 45, 45]     --
# │    │    └─Sequential (base1)           [8, 64, 45, 45]      [8, 64, 45, 45]      37,056
# │    │    └─Sequential (base2)           [8, 64, 45, 45]      [8, 128, 45, 45]     74,112
# │    └─MaxPool2d (5)                     [8, 128, 45, 45]     [8, 128, 22, 22]     --
# │    └─ResBlock (6)                      [8, 128, 22, 22]     [8, 256, 22, 22]     --
# │    │    └─Sequential (base1)           [8, 128, 22, 22]     [8, 128, 22, 22]     147,840
# │    │    └─Sequential (base2)           [8, 128, 22, 22]     [8, 256, 22, 22]     295,680
# │    └─MaxPool2d (7)                     [8, 256, 22, 22]     [8, 256, 11, 11]     --
# │    └─Conv2d (8)                        [8, 256, 11, 11]     [8, 512, 9, 9]       1,180,160
# │    └─MaxPool2d (9)                     [8, 512, 9, 9]       [8, 512, 4, 4]       --
# │    └─Flatten (10)                      [8, 512, 4, 4]       [8, 8192]            --
# │    └─Linear (11)                       [8, 8192]            [8, 4]               32,772
# ├─Linear (hint_fc)                       [8, 2]               [8, 4]               12
# ├─Linear (all_fc)                        [8, 8]               [8, 4]               36
# ====================================================================================================
# Total params: 1,796,000
# Trainable params: 1,796,000
# Non-trainable params: 0
# Total mult-adds (G): 6.16
# ====================================================================================================
# Input size (MB): 1.04
# Forward/backward pass size (MB): 312.60
# Params size (MB): 7.18
# Estimated Total Size (MB): 320.82
# ====================================================================================================

# %%
# %autoreload 2
from peak_detection_2d.loss import WeightedBoundingBoxIoULoss
import logging
import json
import os

import torch
from torch import nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision.transforms import Compose

from peak_detection_2d.utils import (
    plot_sample_predictions,
    plot_history,
)
from peak_detection_2d.dataset import MultiHDF5Dataset, ToTensor, Padding
from peak_detection_2d.model import (
    PeakDetectionNet,
    train_val_step,
    train_val_step_wiou,
)

logging.basicConfig(
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO,
)
# experiment specific
result_parent_dir = "/cmnfs/proj/ORIGINS/data/brain/FreshFrozenBrain/SingleShot/DDA/"
result_base_dir = "frame0_1830_ssDDA_P064428_Fresh1_5ug_R1_BD5_1_4921_ScanByScan_RTtol0.9_threshold_missabthres0.5_convergence_NoIntercept_pred_mzBinDigits2_imPeakWidth4_deltaMobilityThres80"
result_dir = os.path.join(result_parent_dir, result_base_dir)
peak_selection_dir = os.path.join(result_dir, "peak_selection_model_1out64_lr01")
if not os.path.exists(peak_selection_dir):
    os.makedirs(peak_selection_dir)

num_epoch = 5
patience = 10
inital_lr = 0.001
batch_size = 64

random_state = 42
device = "cuda" if torch.cuda.is_available() else "cpu"
logging.info("Using device: %s", device)
model = PeakDetectionNet(1, 32).to(device)

loss_func_val = WeightedBoundingBoxIoULoss(reduction="mean", add_diou=False, add_smooth_l1=False)
loss_func_train = WeightedBoundingBoxIoULoss(reduction="mean", add_diou=False, add_smooth_l1=True)
loss_func_l1 = nn.SmoothL1Loss(reduction="mean")
optimizer = torch.optim.Adam(model.parameters(), lr=inital_lr)
scheduler = ReduceLROnPlateau(
    optimizer, mode="min", factor=0.1, patience=3, min_lr=0.000001
)

loss_tracking = {"train": [], "val": []}
iou_tracking = {"train": [], "val": []}
best_loss = float("inf")


with open(os.path.join(result_dir, "param.json"), mode="r", encoding="utf-8") as file:
    config = json.load(file)

hdf5_files = [
    os.path.join(os.path.join(result_dir, "peak_detection_data"), file)
    for file in os.listdir(os.path.join(result_dir, "peak_detection_data"))
    if file.endswith(".h5")
]

# Define transformations (if any)
transformation = Compose([Padding((180, 180)), ToTensor(scale_label=False)])

# Create the dataset
dataset = MultiHDF5Dataset(hdf5_files, transforms=transformation)

# Split the dataset into training and testing sets
train_val_dataset, test_dataset = dataset.split_dataset(
    train_ratio=0.2, seed=random_state
)
train_dataset, val_dataset = train_val_dataset.split_dataset(
    train_ratio=0.8, seed=random_state
)
logging.info("Train dataset size: %d", len(train_dataset))
logging.info("Validation dataset size: %d", len(val_dataset))
logging.info("Test dataset size: %d", len(test_dataset))
# Example usage
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=False
)
val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=1024, shuffle=False
)
test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=1024, shuffle=False
)


for epoch in range(num_epoch):
    logging.info("Epoch %d/%d", epoch + 1, num_epoch)

    training_loss, trainig_iou = train_val_step_wiou(
        train_dataloader, model, loss_func_train, optimizer
    )
    loss_tracking["train"].append(training_loss)
    iou_tracking["train"].append(trainig_iou)

    with torch.inference_mode():
        val_loss, val_iou = train_val_step_wiou(val_dataloader, model, loss_func_val, None)
        loss_tracking["val"].append(val_loss)
        iou_tracking["val"].append(val_iou)
        if val_loss < best_loss:
            logging.info("Saving best model")
            torch.save(
                model.state_dict(), os.path.join(peak_selection_dir, "best_model.pt")
            )
            best_loss = val_loss
            current_patience = patience
        else:
            current_patience -= 1
            if current_patience == 0:
                logging.info("Early stopping")
                break
        scheduler.step(val_loss)
        logging.info(
            "Last learning rate: %s",
            scheduler.get_last_lr(),
        )

    logging.info("Training loss: %.6f, IoU: %.2f", training_loss, trainig_iou)
    logging.info("Validation loss: %.6f, IoU: %.6f", val_loss, val_iou)

# Plot history
with open(os.path.join(peak_selection_dir, "loss.json"), "w", encoding="utf-8") as fp:
    json.dump(loss_tracking, fp)
with open(os.path.join(peak_selection_dir, "iou.json"), "w", encoding="utf-8") as fp:
    json.dump(iou_tracking, fp)

plot_history(loss_tracking, "loss", save_dir=peak_selection_dir)
plot_history(iou_tracking, "iou", save_dir=peak_selection_dir)

# Plot sample predictions
plot_sample_predictions(
    test_dataset,
    model=model,
    n=5,
    save_dir=os.path.join(peak_selection_dir, "sample_predictions"),
)
# Out:
# 2024-05-28 15:52:02,348 - root - INFO - Using device: cuda
# 2024-05-28 15:52:02,396 - root - INFO - Train dataset size: 2300
# 2024-05-28 15:52:02,397 - root - INFO - Validation dataset size: 575
# 2024-05-28 15:52:02,398 - root - INFO - Test dataset size: 11504
# 2024-05-28 15:52:02,400 - root - INFO - Epoch 1/5
# 2024-05-28 15:52:02,401 - peak_detection_2d.model - INFO - model is in training mode
# 2024-05-28 15:52:02,692 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,693 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7384, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2603, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(69., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(95., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,698 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,699 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.8303, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.1944, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(76., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(66., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,703 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,703 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7972, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.1898, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(114., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(116., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,708 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,708 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-1.3171, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.6684, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(82., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(140., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,713 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,713 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7883, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2951, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(105., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(94., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,717 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,718 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6731, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2665, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(58., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(87., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,723 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,723 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6738, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4604, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(102., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(113., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,727 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,728 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9377, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.5590, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(94., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(91., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,733 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,733 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8278, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3172, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(73., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(62., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,738 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,738 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.1724, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.6332, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(97., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(104., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,743 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,743 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-1.6128, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.5548, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(63., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(93., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,748 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,749 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7364, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(4.9758, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(106., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(107., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,753 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,753 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-10.0080, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.9245, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(84., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(114., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,758 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,759 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.3328, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.5594, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(56., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(80., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,763 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,763 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6983, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2333, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(75., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(82., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,768 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,768 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7631, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3548, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(115., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(73., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,773 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,773 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8134, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3071, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(45., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(83., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,777 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,778 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8630, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.7012, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(115., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(73., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,782 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,783 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.1889, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(6.3077, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(90., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(118., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,787 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,788 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.8517, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4062, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(135., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(112., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,792 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,793 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8650, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.1697, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(111., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(110., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,797 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,798 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7199, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2621, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(42., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(86., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,802 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,802 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.6919, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.6430, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(91., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(102., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,807 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,807 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6500, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.5332, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(69., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(173., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,811 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,812 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.0314, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3647, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(132., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(90., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,816 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,817 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-5.7232, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(7.0439, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(84., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(118., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,821 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,822 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9937, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.7603, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(88., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(73., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,826 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,827 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7600, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2724, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(66., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(68., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,831 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,832 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9891, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4013, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(111., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(56., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,836 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,836 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9212, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4178, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(100., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(67., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,841 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,842 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7693, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2439, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(97., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(80., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,846 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,846 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5929, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.0359, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(78., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(132., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,851 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,852 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.4176, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(6.0894, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(96., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(105., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,856 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,857 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8507, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3508, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(118., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(93., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,861 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,862 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8731, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3112, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(85., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(110., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,866 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,867 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8032, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2884, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(76., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(105., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,871 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,872 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7386, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2724, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(61., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(84., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,876 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,877 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.3066, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.9516, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(83., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(100., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,881 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,882 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7993, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3034, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(87., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(101., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,886 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,887 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7654, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2805, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(102., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(95., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,891 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,892 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.1894, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(6.3112, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(47., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(100., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,896 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,897 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-4.0826, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.0677, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(74., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(64., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,901 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,902 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8060, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2895, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(90., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(87., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,906 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,907 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5817, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4812, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(88., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(105., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,912 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,912 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7385, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2364, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(73., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(59., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,917 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,918 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.0729, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.5178, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(118., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(84., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,922 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,923 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7247, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2366, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(48., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(104., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,927 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,928 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9316, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3974, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(54., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(76., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,932 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,933 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7502, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2781, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(64., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(99., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,938 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,938 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9747, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4142, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(126., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(77., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,943 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,943 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5383, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4476, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(79., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(105., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,948 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,949 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7413, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2577, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(78., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(104., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,953 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,954 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8285, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3076, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(64., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(58., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,958 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,959 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7748, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2964, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(79., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(83., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,964 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,964 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9339, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3540, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(126., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(99., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,969 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,969 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7760, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.3028, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(88., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(89., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,974 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,975 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-5.8354, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(7.1467, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(123., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(97., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,979 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,980 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7541, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.2584, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(96., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(104., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,985 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:02,985 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5615, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(5.4945, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(70., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(89., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:02,990 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:52:03,000 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,000 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7384, device='cuda:0'), y1: tensor(5.2603, device='cuda:0'), x2: tensor(69., device='cuda:0'), y2: tensor(95., device='cuda:0')
# 2024-05-28 15:52:03,005 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,006 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.8303, device='cuda:0'), y1: tensor(8.1944, device='cuda:0'), x2: tensor(76., device='cuda:0'), y2: tensor(66., device='cuda:0')
# 2024-05-28 15:52:03,010 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,011 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7972, device='cuda:0'), y1: tensor(5.1898, device='cuda:0'), x2: tensor(114., device='cuda:0'), y2: tensor(116., device='cuda:0')
# 2024-05-28 15:52:03,015 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,016 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-1.3171, device='cuda:0'), y1: tensor(9.6684, device='cuda:0'), x2: tensor(82., device='cuda:0'), y2: tensor(140., device='cuda:0')
# 2024-05-28 15:52:03,020 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,021 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7883, device='cuda:0'), y1: tensor(5.2951, device='cuda:0'), x2: tensor(105., device='cuda:0'), y2: tensor(94., device='cuda:0')
# 2024-05-28 15:52:03,026 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,026 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6731, device='cuda:0'), y1: tensor(5.2665, device='cuda:0'), x2: tensor(58., device='cuda:0'), y2: tensor(87., device='cuda:0')
# 2024-05-28 15:52:03,031 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,032 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6738, device='cuda:0'), y1: tensor(5.4604, device='cuda:0'), x2: tensor(102., device='cuda:0'), y2: tensor(113., device='cuda:0')
# 2024-05-28 15:52:03,036 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,037 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9377, device='cuda:0'), y1: tensor(5.5590, device='cuda:0'), x2: tensor(94., device='cuda:0'), y2: tensor(91., device='cuda:0')
# 2024-05-28 15:52:03,042 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,042 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8278, device='cuda:0'), y1: tensor(5.3172, device='cuda:0'), x2: tensor(73., device='cuda:0'), y2: tensor(62., device='cuda:0')
# 2024-05-28 15:52:03,047 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,047 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.1724, device='cuda:0'), y1: tensor(5.6332, device='cuda:0'), x2: tensor(97., device='cuda:0'), y2: tensor(104., device='cuda:0')
# 2024-05-28 15:52:03,052 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,053 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-1.6128, device='cuda:0'), y1: tensor(9.5548, device='cuda:0'), x2: tensor(63., device='cuda:0'), y2: tensor(93., device='cuda:0')
# 2024-05-28 15:52:03,057 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,058 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7364, device='cuda:0'), y1: tensor(4.9758, device='cuda:0'), x2: tensor(106., device='cuda:0'), y2: tensor(107., device='cuda:0')
# 2024-05-28 15:52:03,062 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,063 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-10.0080, device='cuda:0'), y1: tensor(5.9245, device='cuda:0'), x2: tensor(84., device='cuda:0'), y2: tensor(114., device='cuda:0')
# 2024-05-28 15:52:03,068 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,068 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.3328, device='cuda:0'), y1: tensor(8.5594, device='cuda:0'), x2: tensor(56., device='cuda:0'), y2: tensor(80., device='cuda:0')
# 2024-05-28 15:52:03,073 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,074 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6983, device='cuda:0'), y1: tensor(5.2333, device='cuda:0'), x2: tensor(75., device='cuda:0'), y2: tensor(82., device='cuda:0')
# 2024-05-28 15:52:03,078 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,079 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7631, device='cuda:0'), y1: tensor(5.3548, device='cuda:0'), x2: tensor(115., device='cuda:0'), y2: tensor(73., device='cuda:0')
# 2024-05-28 15:52:03,083 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,084 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8134, device='cuda:0'), y1: tensor(5.3071, device='cuda:0'), x2: tensor(45., device='cuda:0'), y2: tensor(83., device='cuda:0')
# 2024-05-28 15:52:03,089 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,089 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8630, device='cuda:0'), y1: tensor(5.7012, device='cuda:0'), x2: tensor(115., device='cuda:0'), y2: tensor(73., device='cuda:0')
# 2024-05-28 15:52:03,094 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,095 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.1889, device='cuda:0'), y1: tensor(6.3077, device='cuda:0'), x2: tensor(90., device='cuda:0'), y2: tensor(118., device='cuda:0')
# 2024-05-28 15:52:03,099 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,100 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.8517, device='cuda:0'), y1: tensor(5.4062, device='cuda:0'), x2: tensor(135., device='cuda:0'), y2: tensor(112., device='cuda:0')
# 2024-05-28 15:52:03,105 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,105 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8650, device='cuda:0'), y1: tensor(5.1697, device='cuda:0'), x2: tensor(111., device='cuda:0'), y2: tensor(110., device='cuda:0')
# 2024-05-28 15:52:03,110 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,110 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7199, device='cuda:0'), y1: tensor(5.2621, device='cuda:0'), x2: tensor(42., device='cuda:0'), y2: tensor(86., device='cuda:0')
# 2024-05-28 15:52:03,115 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,116 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.6919, device='cuda:0'), y1: tensor(5.6430, device='cuda:0'), x2: tensor(91., device='cuda:0'), y2: tensor(102., device='cuda:0')
# 2024-05-28 15:52:03,120 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,121 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6500, device='cuda:0'), y1: tensor(5.5332, device='cuda:0'), x2: tensor(69., device='cuda:0'), y2: tensor(173., device='cuda:0')
# 2024-05-28 15:52:03,126 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,126 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.0314, device='cuda:0'), y1: tensor(5.3647, device='cuda:0'), x2: tensor(132., device='cuda:0'), y2: tensor(90., device='cuda:0')
# 2024-05-28 15:52:03,131 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,132 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-5.7232, device='cuda:0'), y1: tensor(7.0439, device='cuda:0'), x2: tensor(84., device='cuda:0'), y2: tensor(118., device='cuda:0')
# 2024-05-28 15:52:03,136 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,137 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9937, device='cuda:0'), y1: tensor(5.7603, device='cuda:0'), x2: tensor(88., device='cuda:0'), y2: tensor(73., device='cuda:0')
# 2024-05-28 15:52:03,141 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,142 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7600, device='cuda:0'), y1: tensor(5.2724, device='cuda:0'), x2: tensor(66., device='cuda:0'), y2: tensor(68., device='cuda:0')
# 2024-05-28 15:52:03,147 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,147 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9891, device='cuda:0'), y1: tensor(5.4013, device='cuda:0'), x2: tensor(111., device='cuda:0'), y2: tensor(56., device='cuda:0')
# 2024-05-28 15:52:03,152 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,153 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9212, device='cuda:0'), y1: tensor(5.4178, device='cuda:0'), x2: tensor(100., device='cuda:0'), y2: tensor(67., device='cuda:0')
# 2024-05-28 15:52:03,158 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,158 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7693, device='cuda:0'), y1: tensor(5.2439, device='cuda:0'), x2: tensor(97., device='cuda:0'), y2: tensor(80., device='cuda:0')
# 2024-05-28 15:52:03,163 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,163 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5929, device='cuda:0'), y1: tensor(5.0359, device='cuda:0'), x2: tensor(78., device='cuda:0'), y2: tensor(132., device='cuda:0')
# 2024-05-28 15:52:03,168 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,169 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.4176, device='cuda:0'), y1: tensor(6.0894, device='cuda:0'), x2: tensor(96., device='cuda:0'), y2: tensor(105., device='cuda:0')
# 2024-05-28 15:52:03,173 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,174 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8507, device='cuda:0'), y1: tensor(5.3508, device='cuda:0'), x2: tensor(118., device='cuda:0'), y2: tensor(93., device='cuda:0')
# 2024-05-28 15:52:03,179 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,179 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8731, device='cuda:0'), y1: tensor(5.3112, device='cuda:0'), x2: tensor(85., device='cuda:0'), y2: tensor(110., device='cuda:0')
# 2024-05-28 15:52:03,184 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,185 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8032, device='cuda:0'), y1: tensor(5.2884, device='cuda:0'), x2: tensor(76., device='cuda:0'), y2: tensor(105., device='cuda:0')
# 2024-05-28 15:52:03,189 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,190 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7386, device='cuda:0'), y1: tensor(5.2724, device='cuda:0'), x2: tensor(61., device='cuda:0'), y2: tensor(84., device='cuda:0')
# 2024-05-28 15:52:03,194 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,195 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.3066, device='cuda:0'), y1: tensor(8.9516, device='cuda:0'), x2: tensor(83., device='cuda:0'), y2: tensor(100., device='cuda:0')
# 2024-05-28 15:52:03,200 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,200 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7993, device='cuda:0'), y1: tensor(5.3034, device='cuda:0'), x2: tensor(87., device='cuda:0'), y2: tensor(101., device='cuda:0')
# 2024-05-28 15:52:03,205 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,206 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7654, device='cuda:0'), y1: tensor(5.2805, device='cuda:0'), x2: tensor(102., device='cuda:0'), y2: tensor(95., device='cuda:0')
# 2024-05-28 15:52:03,210 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,211 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.1894, device='cuda:0'), y1: tensor(6.3112, device='cuda:0'), x2: tensor(47., device='cuda:0'), y2: tensor(100., device='cuda:0')
# 2024-05-28 15:52:03,216 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,216 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-4.0826, device='cuda:0'), y1: tensor(8.0677, device='cuda:0'), x2: tensor(74., device='cuda:0'), y2: tensor(64., device='cuda:0')
# 2024-05-28 15:52:03,221 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,222 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8060, device='cuda:0'), y1: tensor(5.2895, device='cuda:0'), x2: tensor(90., device='cuda:0'), y2: tensor(87., device='cuda:0')
# 2024-05-28 15:52:03,226 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,227 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5817, device='cuda:0'), y1: tensor(5.4812, device='cuda:0'), x2: tensor(88., device='cuda:0'), y2: tensor(105., device='cuda:0')
# 2024-05-28 15:52:03,232 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,232 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7385, device='cuda:0'), y1: tensor(5.2364, device='cuda:0'), x2: tensor(73., device='cuda:0'), y2: tensor(59., device='cuda:0')
# 2024-05-28 15:52:03,237 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,238 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.0729, device='cuda:0'), y1: tensor(5.5178, device='cuda:0'), x2: tensor(118., device='cuda:0'), y2: tensor(84., device='cuda:0')
# 2024-05-28 15:52:03,243 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,243 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7247, device='cuda:0'), y1: tensor(5.2366, device='cuda:0'), x2: tensor(48., device='cuda:0'), y2: tensor(104., device='cuda:0')
# 2024-05-28 15:52:03,248 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,249 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9316, device='cuda:0'), y1: tensor(5.3974, device='cuda:0'), x2: tensor(54., device='cuda:0'), y2: tensor(76., device='cuda:0')
# 2024-05-28 15:52:03,253 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,254 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7502, device='cuda:0'), y1: tensor(5.2781, device='cuda:0'), x2: tensor(64., device='cuda:0'), y2: tensor(99., device='cuda:0')
# 2024-05-28 15:52:03,259 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,259 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9747, device='cuda:0'), y1: tensor(5.4142, device='cuda:0'), x2: tensor(126., device='cuda:0'), y2: tensor(77., device='cuda:0')
# 2024-05-28 15:52:03,264 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,265 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5383, device='cuda:0'), y1: tensor(5.4476, device='cuda:0'), x2: tensor(79., device='cuda:0'), y2: tensor(105., device='cuda:0')
# 2024-05-28 15:52:03,269 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,270 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7413, device='cuda:0'), y1: tensor(5.2577, device='cuda:0'), x2: tensor(78., device='cuda:0'), y2: tensor(104., device='cuda:0')
# 2024-05-28 15:52:03,275 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,275 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8285, device='cuda:0'), y1: tensor(5.3076, device='cuda:0'), x2: tensor(64., device='cuda:0'), y2: tensor(58., device='cuda:0')
# 2024-05-28 15:52:03,280 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,281 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7748, device='cuda:0'), y1: tensor(5.2964, device='cuda:0'), x2: tensor(79., device='cuda:0'), y2: tensor(83., device='cuda:0')
# 2024-05-28 15:52:03,285 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,286 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.9339, device='cuda:0'), y1: tensor(5.3540, device='cuda:0'), x2: tensor(126., device='cuda:0'), y2: tensor(99., device='cuda:0')
# 2024-05-28 15:52:03,291 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,291 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7760, device='cuda:0'), y1: tensor(5.3028, device='cuda:0'), x2: tensor(88., device='cuda:0'), y2: tensor(89., device='cuda:0')
# 2024-05-28 15:52:03,296 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,297 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-5.8354, device='cuda:0'), y1: tensor(7.1467, device='cuda:0'), x2: tensor(123., device='cuda:0'), y2: tensor(97., device='cuda:0')
# 2024-05-28 15:52:03,301 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,302 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7541, device='cuda:0'), y1: tensor(5.2584, device='cuda:0'), x2: tensor(96., device='cuda:0'), y2: tensor(104., device='cuda:0')
# 2024-05-28 15:52:03,307 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,308 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5615, device='cuda:0'), y1: tensor(5.4945, device='cuda:0'), x2: tensor(70., device='cuda:0'), y2: tensor(89., device='cuda:0')
# 2024-05-28 15:52:03,312 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:52:03,314 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:52:03,315 - peak_detection_2d.loss - INFO - iou metric: 0.0
# 2024-05-28 15:52:03,583 - peak_detection_2d.model - INFO - running iou: 0.0
# 2024-05-28 15:52:03,855 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,856 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-10.1120, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.4637, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(96., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(86., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,861 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,861 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.5382, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.9135, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(109., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(85., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,866 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,867 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.2940, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(11.6294, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(126., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(97., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,871 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,871 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.1341, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.7458, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(79., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(103., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,875 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,876 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8577, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(6.8503, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(107., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(97., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,880 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,881 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-9.0142, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.9708, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(79., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(90., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,885 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,886 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.6825, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(7.4851, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(66., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(93., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,890 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,891 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7992, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.8967, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(96., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(71., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,895 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,895 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.7566, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.9877, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(85., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(112., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,900 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,900 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.5988, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(6.5419, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(84., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(98., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,905 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,905 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-8.8970, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.8568, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(87., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(65., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,909 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,910 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-3.6514, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.0067, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(76., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(67., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,914 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,915 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-6.5502, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(9.5132, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(99., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(62., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,919 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,920 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.3863, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(8.0618, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(83., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(91., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,924 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:52:03,925 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-7.3765, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(7.6960, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(65., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(116., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:52:03,929 - peak_detection_2d.loss - WARNING - Union box is empty
# ...
# 2024-05-28 15:53:30,540 - peak_detection_2d.loss - INFO - wiou loss: 0.777813196182251
# 2024-05-28 15:53:30,540 - peak_detection_2d.loss - INFO - iou metric: 0.22218680381774902
# 2024-05-28 15:53:30,742 - peak_detection_2d.model - INFO - running iou: 1.9253355860710144
# 2024-05-28 15:53:31,008 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1940, device='cuda:0')
# 2024-05-28 15:53:31,031 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1940, device='cuda:0')
# 2024-05-28 15:53:31,033 - peak_detection_2d.loss - INFO - wiou loss: 0.8059502840042114
# 2024-05-28 15:53:31,034 - peak_detection_2d.loss - INFO - iou metric: 0.19404971599578857
# 2024-05-28 15:53:31,236 - peak_detection_2d.model - INFO - running iou: 2.119385302066803
# 2024-05-28 15:53:31,502 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1567, device='cuda:0')
# 2024-05-28 15:53:31,525 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1567, device='cuda:0')
# 2024-05-28 15:53:31,528 - peak_detection_2d.loss - INFO - wiou loss: 0.8433223366737366
# 2024-05-28 15:53:31,528 - peak_detection_2d.loss - INFO - iou metric: 0.15667766332626343
# 2024-05-28 15:53:31,727 - peak_detection_2d.model - INFO - running iou: 2.2760629653930664
# 2024-05-28 15:53:31,993 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0900, device='cuda:0')
# 2024-05-28 15:53:32,016 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0900, device='cuda:0')
# 2024-05-28 15:53:32,019 - peak_detection_2d.loss - INFO - wiou loss: 0.9100274443626404
# 2024-05-28 15:53:32,019 - peak_detection_2d.loss - INFO - iou metric: 0.08997255563735962
# 2024-05-28 15:53:32,220 - peak_detection_2d.model - INFO - running iou: 2.366035521030426
# 2024-05-28 15:53:32,487 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0712, device='cuda:0')
# 2024-05-28 15:53:32,509 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0712, device='cuda:0')
# 2024-05-28 15:53:32,512 - peak_detection_2d.loss - INFO - wiou loss: 0.9288488626480103
# 2024-05-28 15:53:32,512 - peak_detection_2d.loss - INFO - iou metric: 0.07115113735198975
# 2024-05-28 15:53:32,710 - peak_detection_2d.model - INFO - running iou: 2.4371866583824158
# 2024-05-28 15:53:32,977 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1290, device='cuda:0')
# 2024-05-28 15:53:33,000 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1290, device='cuda:0')
# 2024-05-28 15:53:33,002 - peak_detection_2d.loss - INFO - wiou loss: 0.8710261583328247
# 2024-05-28 15:53:33,003 - peak_detection_2d.loss - INFO - iou metric: 0.1289738416671753
# 2024-05-28 15:53:33,202 - peak_detection_2d.model - INFO - running iou: 2.566160500049591
# 2024-05-28 15:53:33,469 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1346, device='cuda:0')
# 2024-05-28 15:53:33,492 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1346, device='cuda:0')
# 2024-05-28 15:53:33,495 - peak_detection_2d.loss - INFO - wiou loss: 0.8654001951217651
# 2024-05-28 15:53:33,495 - peak_detection_2d.loss - INFO - iou metric: 0.13459980487823486
# 2024-05-28 15:53:33,697 - peak_detection_2d.model - INFO - running iou: 2.700760304927826
# 2024-05-28 15:53:33,964 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1360, device='cuda:0')
# 2024-05-28 15:53:33,987 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1360, device='cuda:0')
# 2024-05-28 15:53:33,989 - peak_detection_2d.loss - INFO - wiou loss: 0.8640403747558594
# 2024-05-28 15:53:33,990 - peak_detection_2d.loss - INFO - iou metric: 0.13595962524414062
# 2024-05-28 15:53:34,188 - peak_detection_2d.model - INFO - running iou: 2.8367199301719666
# 2024-05-28 15:53:34,455 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1968, device='cuda:0')
# 2024-05-28 15:53:34,478 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1968, device='cuda:0')
# 2024-05-28 15:53:34,481 - peak_detection_2d.loss - INFO - wiou loss: 0.8032431602478027
# 2024-05-28 15:53:34,482 - peak_detection_2d.loss - INFO - iou metric: 0.19675683975219727
# 2024-05-28 15:53:34,680 - peak_detection_2d.model - INFO - running iou: 3.033476769924164
# 2024-05-28 15:53:34,947 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1055, device='cuda:0')
# 2024-05-28 15:53:34,970 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1055, device='cuda:0')
# 2024-05-28 15:53:34,972 - peak_detection_2d.loss - INFO - wiou loss: 0.8945167660713196
# 2024-05-28 15:53:34,973 - peak_detection_2d.loss - INFO - iou metric: 0.10548323392868042
# 2024-05-28 15:53:35,174 - peak_detection_2d.model - INFO - running iou: 3.1389600038528442
# 2024-05-28 15:53:35,441 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1368, device='cuda:0')
# 2024-05-28 15:53:35,465 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1368, device='cuda:0')
# 2024-05-28 15:53:35,467 - peak_detection_2d.loss - INFO - wiou loss: 0.8632310628890991
# 2024-05-28 15:53:35,468 - peak_detection_2d.loss - INFO - iou metric: 0.13676893711090088
# 2024-05-28 15:53:35,666 - peak_detection_2d.model - INFO - running iou: 3.275728940963745
# 2024-05-28 15:53:35,935 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2504, device='cuda:0')
# 2024-05-28 15:53:35,957 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2504, device='cuda:0')
# 2024-05-28 15:53:35,960 - peak_detection_2d.loss - INFO - wiou loss: 0.7495843172073364
# 2024-05-28 15:53:35,960 - peak_detection_2d.loss - INFO - iou metric: 0.2504156827926636
# 2024-05-28 15:53:36,159 - peak_detection_2d.model - INFO - running iou: 3.5261446237564087
# 2024-05-28 15:53:36,427 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2023, device='cuda:0')
# 2024-05-28 15:53:36,450 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2023, device='cuda:0')
# 2024-05-28 15:53:36,452 - peak_detection_2d.loss - INFO - wiou loss: 0.7977334856987
# 2024-05-28 15:53:36,453 - peak_detection_2d.loss - INFO - iou metric: 0.20226651430130005
# 2024-05-28 15:53:36,654 - peak_detection_2d.model - INFO - running iou: 3.7284111380577087
# 2024-05-28 15:53:36,922 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1988, device='cuda:0')
# 2024-05-28 15:53:36,945 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1988, device='cuda:0')
# 2024-05-28 15:53:36,948 - peak_detection_2d.loss - INFO - wiou loss: 0.8012265563011169
# 2024-05-28 15:53:36,949 - peak_detection_2d.loss - INFO - iou metric: 0.19877344369888306
# 2024-05-28 15:53:37,149 - peak_detection_2d.model - INFO - running iou: 3.927184581756592
# 2024-05-28 15:53:37,416 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1880, device='cuda:0')
# 2024-05-28 15:53:37,439 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1880, device='cuda:0')
# 2024-05-28 15:53:37,441 - peak_detection_2d.loss - INFO - wiou loss: 0.811980664730072
# 2024-05-28 15:53:37,442 - peak_detection_2d.loss - INFO - iou metric: 0.18801933526992798
# 2024-05-28 15:53:37,639 - peak_detection_2d.model - INFO - running iou: 4.11520391702652
# 2024-05-28 15:53:37,906 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2526, device='cuda:0')
# 2024-05-28 15:53:37,929 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2526, device='cuda:0')
# 2024-05-28 15:53:37,931 - peak_detection_2d.loss - INFO - wiou loss: 0.7473822236061096
# 2024-05-28 15:53:37,931 - peak_detection_2d.loss - INFO - iou metric: 0.2526177763938904
# 2024-05-28 15:53:38,132 - peak_detection_2d.model - INFO - running iou: 4.36782169342041
# 2024-05-28 15:53:38,398 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1325, device='cuda:0')
# 2024-05-28 15:53:38,421 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1325, device='cuda:0')
# 2024-05-28 15:53:38,424 - peak_detection_2d.loss - INFO - wiou loss: 0.8675161600112915
# 2024-05-28 15:53:38,425 - peak_detection_2d.loss - INFO - iou metric: 0.1324838399887085
# 2024-05-28 15:53:38,623 - peak_detection_2d.model - INFO - running iou: 4.500305533409119
# 2024-05-28 15:53:38,890 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2322, device='cuda:0')
# 2024-05-28 15:53:38,913 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2322, device='cuda:0')
# 2024-05-28 15:53:38,915 - peak_detection_2d.loss - INFO - wiou loss: 0.7678430676460266
# 2024-05-28 15:53:38,915 - peak_detection_2d.loss - INFO - iou metric: 0.2321569323539734
# 2024-05-28 15:53:39,113 - peak_detection_2d.model - INFO - running iou: 4.732462465763092
# 2024-05-28 15:53:39,380 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2060, device='cuda:0')
# 2024-05-28 15:53:39,404 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2060, device='cuda:0')
# 2024-05-28 15:53:39,406 - peak_detection_2d.loss - INFO - wiou loss: 0.794041633605957
# 2024-05-28 15:53:39,407 - peak_detection_2d.loss - INFO - iou metric: 0.20595836639404297
# 2024-05-28 15:53:39,608 - peak_detection_2d.model - INFO - running iou: 4.938420832157135
# 2024-05-28 15:53:39,875 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1983, device='cuda:0')
# 2024-05-28 15:53:39,898 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1983, device='cuda:0')
# 2024-05-28 15:53:39,900 - peak_detection_2d.loss - INFO - wiou loss: 0.8016611933708191
# 2024-05-28 15:53:39,900 - peak_detection_2d.loss - INFO - iou metric: 0.1983388066291809
# 2024-05-28 15:53:40,098 - peak_detection_2d.model - INFO - running iou: 5.136759638786316
# 2024-05-28 15:53:40,364 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1669, device='cuda:0')
# 2024-05-28 15:53:40,387 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1669, device='cuda:0')
# 2024-05-28 15:53:40,389 - peak_detection_2d.loss - INFO - wiou loss: 0.8331416845321655
# 2024-05-28 15:53:40,390 - peak_detection_2d.loss - INFO - iou metric: 0.16685831546783447
# 2024-05-28 15:53:40,591 - peak_detection_2d.model - INFO - running iou: 5.30361795425415
# 2024-05-28 15:53:40,864 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1222, device='cuda:0')
# 2024-05-28 15:53:40,887 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1222, device='cuda:0')
# 2024-05-28 15:53:40,889 - peak_detection_2d.loss - INFO - wiou loss: 0.8777934908866882
# 2024-05-28 15:53:40,890 - peak_detection_2d.loss - INFO - iou metric: 0.12220650911331177
# 2024-05-28 15:53:41,090 - peak_detection_2d.model - INFO - running iou: 5.425824463367462
# 2024-05-28 15:53:41,357 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1559, device='cuda:0')
# 2024-05-28 15:53:41,379 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1559, device='cuda:0')
# 2024-05-28 15:53:41,381 - peak_detection_2d.loss - INFO - wiou loss: 0.8440663814544678
# 2024-05-28 15:53:41,382 - peak_detection_2d.loss - INFO - iou metric: 0.15593361854553223
# 2024-05-28 15:53:41,580 - peak_detection_2d.model - INFO - running iou: 5.581758081912994
# 2024-05-28 15:53:41,847 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2090, device='cuda:0')
# 2024-05-28 15:53:41,870 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.2090, device='cuda:0')
# 2024-05-28 15:53:41,873 - peak_detection_2d.loss - INFO - wiou loss: 0.7909892201423645
# 2024-05-28 15:53:41,873 - peak_detection_2d.loss - INFO - iou metric: 0.2090107798576355
# 2024-05-28 15:53:42,072 - peak_detection_2d.model - INFO - running iou: 5.79076886177063
# 2024-05-28 15:53:42,338 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0708, device='cuda:0')
# 2024-05-28 15:53:42,362 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0708, device='cuda:0')
# 2024-05-28 15:53:42,364 - peak_detection_2d.loss - INFO - wiou loss: 0.9292330145835876
# 2024-05-28 15:53:42,365 - peak_detection_2d.loss - INFO - iou metric: 0.07076698541641235
# 2024-05-28 15:53:42,563 - peak_detection_2d.model - INFO - running iou: 5.861535847187042
# 2024-05-28 15:53:42,831 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1908, device='cuda:0')
# 2024-05-28 15:53:42,854 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1908, device='cuda:0')
# 2024-05-28 15:53:42,857 - peak_detection_2d.loss - INFO - wiou loss: 0.8092046976089478
# 2024-05-28 15:53:42,857 - peak_detection_2d.loss - INFO - iou metric: 0.19079530239105225
# 2024-05-28 15:53:43,055 - peak_detection_2d.model - INFO - running iou: 6.0523311495780945
# 2024-05-28 15:53:43,322 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1592, device='cuda:0')
# 2024-05-28 15:53:43,345 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1592, device='cuda:0')
# 2024-05-28 15:53:43,347 - peak_detection_2d.loss - INFO - wiou loss: 0.8407736420631409
# 2024-05-28 15:53:43,348 - peak_detection_2d.loss - INFO - iou metric: 0.15922635793685913
# 2024-05-28 15:53:43,549 - peak_detection_2d.model - INFO - running iou: 6.211557507514954
# 2024-05-28 15:53:43,802 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1489, device='cuda:0')
# 2024-05-28 15:53:43,824 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1489, device='cuda:0')
# 2024-05-28 15:53:43,827 - peak_detection_2d.loss - INFO - wiou loss: 0.8510898947715759
# 2024-05-28 15:53:43,827 - peak_detection_2d.loss - INFO - iou metric: 0.14891010522842407
# 2024-05-28 15:53:44,018 - peak_detection_2d.model - INFO - running iou: 6.360467612743378
# 2024-05-28 15:53:44,019 - peak_detection_2d.model - INFO - model is in evaluation mode
# 2024-05-28 15:53:46,247 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0597, device='cuda:0')
# 2024-05-28 15:53:46,419 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0597, device='cuda:0')
# 2024-05-28 15:53:46,430 - peak_detection_2d.loss - INFO - wiou loss: 0.9402759075164795
# 2024-05-28 15:53:46,431 - peak_detection_2d.loss - INFO - iou metric: 0.05972409248352051
# 2024-05-28 15:53:46,432 - peak_detection_2d.model - INFO - running iou: 0.05972409248352051
# 2024-05-28 15:53:46,433 - root - INFO - Last learning rate: [0.001]
# 2024-05-28 15:53:46,434 - root - INFO - Training loss: 15.760577, IoU: 0.18
# 2024-05-28 15:53:46,434 - root - INFO - Validation loss: 0.940276, IoU: 0.059724
# 2024-05-28 15:53:47,049 - peak_detection_2d.utils - INFO - Output: tensor([[61.5481, 73.1648, 85.2521, 77.4163]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:53:47,054 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:53:47,055 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:53:47,774 - peak_detection_2d.utils - INFO - Output: tensor([[60.4341, 66.6672, 87.2659, 75.0357]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:53:47,778 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0060, device='cuda:0')
# 2024-05-28 15:53:47,779 - peak_detection_2d.loss - INFO - wiou loss: 0.9940019845962524
# 2024-05-28 15:53:48,898 - peak_detection_2d.utils - INFO - Output: tensor([[42.9910, 92.3978, 78.9627, 92.6452]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:53:48,904 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:53:48,905 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:53:49,581 - peak_detection_2d.utils - INFO - Output: tensor([[53.0278, 83.7578, 76.9753, 82.5674]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:53:49,587 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:53:49,588 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:53:50,251 - peak_detection_2d.utils - INFO - Output: tensor([[55.9405, 79.7338, 77.7128, 79.6832]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:53:50,256 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:53:50,257 - peak_detection_2d.loss - INFO - wiou loss: 1.0

# %%
plot_sample_predictions(
    test_dataset,
    model=model,
    n=10,
    save_dir=os.path.join(peak_selection_dir, "sample_predictions"),
)
# Out:
# 2024-05-28 15:39:52,362 - peak_detection_2d.utils - INFO - Output: tensor([[-59.8907, -13.3338,  18.1896,  61.5581]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:52,367 - peak_detection_2d.loss - WARNING - Union box is empty
# 2024-05-28 15:39:52,367 - peak_detection_2d.loss - INFO - Union box: x1: tensor(-59.8907, device='cuda:0', grad_fn=<SelectBackward0>), y1: tensor(-13.3338, device='cuda:0', grad_fn=<SelectBackward0>), x2: tensor(295., device='cuda:0', grad_fn=<SelectBackward0>), y2: tensor(145., device='cuda:0', grad_fn=<SelectBackward0>)
# 2024-05-28 15:39:52,371 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:39:52,372 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:39:53,172 - peak_detection_2d.utils - INFO - Output: tensor([[-165.8776, -110.0317,   49.5585,  210.1995]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:53,177 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.1731, device='cuda:0')
# 2024-05-28 15:39:53,179 - peak_detection_2d.loss - INFO - wiou loss: 0.8269315958023071
# 2024-05-28 15:39:53,959 - peak_detection_2d.utils - INFO - Output: tensor([[-152.0838,  -95.5129,   46.3507,  185.5620]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:53,966 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.4422, device='cuda:0')
# 2024-05-28 15:39:53,967 - peak_detection_2d.loss - INFO - wiou loss: 0.5577996969223022
# 2024-05-28 15:39:54,765 - peak_detection_2d.utils - INFO - Output: tensor([[-154.1596,  -97.4612,   49.5914,  186.2334]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:54,770 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:39:54,772 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:39:55,936 - peak_detection_2d.utils - INFO - Output: tensor([[-168.0049, -109.0064,   54.4984,  207.4491]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:55,942 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.5678, device='cuda:0')
# 2024-05-28 15:39:55,944 - peak_detection_2d.loss - INFO - wiou loss: 0.43223410844802856
# 2024-05-28 15:39:56,743 - peak_detection_2d.utils - INFO - Output: tensor([[-169.3820, -109.5344,   54.8915,  209.8105]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:56,749 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.4433, device='cuda:0')
# 2024-05-28 15:39:56,750 - peak_detection_2d.loss - INFO - wiou loss: 0.5566539764404297
# 2024-05-28 15:39:57,503 - peak_detection_2d.utils - INFO - Output: tensor([[-137.1725,  -83.3451,   43.3634,  175.2234]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:57,508 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0951, device='cuda:0')
# 2024-05-28 15:39:57,510 - peak_detection_2d.loss - INFO - wiou loss: 0.9049171209335327
# 2024-05-28 15:39:58,283 - peak_detection_2d.utils - INFO - Output: tensor([[-129.7131,  -70.5861,   43.0450,  156.8740]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:58,288 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:39:58,290 - peak_detection_2d.loss - INFO - wiou loss: 1.0
# 2024-05-28 15:39:59,064 - peak_detection_2d.utils - INFO - Output: tensor([[-178.0642, -120.6559,   56.3208,  229.4970]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:39:59,069 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0.0457, device='cuda:0')
# 2024-05-28 15:39:59,071 - peak_detection_2d.loss - INFO - wiou loss: 0.954278826713562
# 2024-05-28 15:40:00,109 - peak_detection_2d.utils - INFO - Output: tensor([[-159.5604, -115.2711,   55.4915,  198.5241]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2024-05-28 15:40:00,114 - peak_detection_2d.loss - INFO - weighted iou mean: tensor(0., device='cuda:0')
# 2024-05-28 15:40:00,115 - peak_detection_2d.loss - INFO - wiou loss: 1.0

# %%
import gc

torch.cuda.empty_cache()
gc.collect()
# Out:
# 31

# %%
from peak_detection_2d.utils import plot_data_points

# Sample n datapoints from test_dataset
n = 5
sample_indices = np.random.choice(len(test_dataset), n, replace=False)
for i in sample_indices:
    image, hint, label = test_dataset[i]
    output = model(image.unsqueeze(0).float(), hint.unsqueeze(0).float())
    iou = iou_batch(output, label.unsqueeze(0))
    to_plot = {"data": image[0].cpu(), "hint_idx": hint.cpu(), "bbox": label.cpu()}
    plot_data_points(to_plot, pred_bbox=output[0].cpu().detach().numpy(), zoom_in=True)
    plt.title(f"IoU: {iou:.2f}")
    plt.savefig(f"sample_{i}.png", dpi=300)
    plt.close()
